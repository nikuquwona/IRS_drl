# %%
# !pip3 install matplotlib pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import pandas as pd
import math
# 读取CSV文件
data = pd.read_csv('/Users/lhd/Downloads/run-runs_PPO_continuous_env_test_Gaussian_number_2_seed_10-tag-step_rewards_test.csv')
data2 = pd.read_csv('/Users/lhd/Downloads/run-runs_PPO_continuous_env_test_Gaussian_number_15_seed_10-tag-step_rewards_test.csv')


# 获取横坐标和纵坐标数据
steps = data['Step']
reward = data['Value']
reward2 = data2['Value']

snr=[]
for r in reward:
    a = r
    snr_db = 10 * math.log10(a / (10 ** (-80 / 10) / 1000))
    # snr_db=(snr_db-40)/1000000
    snr.append(snr_db)

# 绘制折线图
plt.plot(steps/1000, reward, label='opt')
plt.plot(steps/1000, reward2, label='without opt', color='gray')
# plt.plot(steps/1000, snr, label='SNR (db)',color='green')

# 添加标题和轴标签
plt.title('Reward')
plt.xlabel('Step (k)')
plt.ylabel('P (dbm)')
# 显示图例
plt.legend(loc='lower right')

plt.savefig('figs/number_2_P.png', dpi=1000)
# plt.savefig('figs/number_2_SNR.png', dpi=1000)
# plt.savefig('figs/number_2_P.png', dpi=4000)
# 显示图形
plt.autoscale()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import math
# 读取CSV文件
data = pd.read_csv('/Users/lhd/Downloads/run-runs_PPO_continuous_env_test_Gaussian_number_2_seed_10-tag-step_rewards_test.csv')

# 获取横坐标和纵坐标数据
steps = data['Step']
reward = data['Value']

snr=[]
reward_max=0
for r in reward:
    if r>reward_max:
        reward_max=r    
    a = r
    snr_db = 10 * math.log10(a / (10 ** (-80 / 10) / 1000))
    snr.append(snr_db)
reward_deployment=reward_max
reward_not_deploy=9.477582031886242e-07
reward_not_irs=2.323371178588477e-07##
#这三个图等测试跑完后 重新计算吧

# 绘制柱状图
x=['without_irs','irs_without_opt','irs_opt']
y=[reward_not_irs*10*10**5,reward_not_deploy*10*10**5,reward_deployment*10**5]
# y2=[reward_not_irs,reward_not_deploy,reward_deployment]
# y=y*10**5
# print(y)

width = 3.5
import numpy as np
# x1 = np.arange(len(x))
# x2 = x1 + width

fig = plt.figure(figsize=(3.2, 6))

plt.bar(x, y,width=0.4,label='Series 1', align='center',edgecolor='black')
# plt.bar(x2, y2,width=1,label='Series 2', align='center',edgecolor='black')

# 添加标题和轴标签
# plt.title('PPO')
# plt.xlabel('Step')
plt.ylabel('P  (1e-5 dbm)')
# 显示图例
# plt.legend(loc='lower right')
plt.savefig('figs/number_柱状图.png',dpi=1000)
# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 生成示例数据
x = np.arange(0, 10, 0.1)
y1 = np.sin(x)
y2 = np.exp(-x)

# 创建图形对象和主轴
fig, ax1 = plt.subplots()

# 绘制第一条折线
ax1.plot(x, y1, color='blue')

# 设置主轴标题和纵轴标签
ax1.set_title('Example with Two Y-Axes')
ax1.set_ylabel('Sine Wave', color='blue')

# 创建第二个纵轴并绑定到主轴上
ax2 = ax1.twinx()

# 绘制第二条折线
ax2.plot(x, y2, color='red')

# 设置第二个纵轴标签
ax2.set_ylabel('Exponential Decay', color='red')

# 自动调整 x 轴范围
ax1.autoscale()

# 显示图形
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
a=np.array([50    ,  0.06450139,  4.9       ,  0.6       ,  0.46070215,        0.47197083,  0.4       ,  0.47952116])
b=np.array([50.9238    ,  0.06450139,  4.9       ,  0.6       ,  0.46070215,        0.47197083,  0.4       ,  0.47952116])

s=[]

s.append(a)
s.append(b)

s
# Out:
# [array([50.        ,  0.06450139,  4.9       ,  0.6       ,  0.46070215,
#          0.47197083,  0.4       ,  0.47952116]),
#  array([50.9238    ,  0.06450139,  4.9       ,  0.6       ,  0.46070215,
#          0.47197083,  0.4       ,  0.47952116])]

# %%
a=np.arctan(np.sqrt(3)/1)/(math.pi*2)
b=np.arctan(1/np.sqrt(3))/(math.pi*2)
# np.cos(2*np.pi)
# 60/360  0.16666666666666666
print(a+b)
np.cos(2*math.pi*0.25)
x=[]
x.append((2,3))
x
np.cos(2*math.pi*0.3)
(1,2)[1]
np.arctan(0)/(math.pi*2)
print(np.cos(2*math.pi*0.2))
print(np.cos(2*math.pi*0.8))
# Out:
# 0.25
# 0.30901699437494745
# 0.30901699437494723

# %%
import matplotlib.pyplot as plt

# 横坐标：用户数从5到10
x = [5, 6, 7, 8, 9, 10]

# 纵坐标：用户处奖励（假设有三条折线）
# y1 = [10, 15, 12, 8, 13, 9]
# y2 = [4.895e-07, 5.5255e-07, 6.023282267521897e-07, 6.409124773089139e-07, 7.169332470223632e-07, 8.075037296058803e-07]
# y1 = [0.00022173017673947327,0.0002660762120873679,0.0003104222474352626]
y1=[
    1.2866427581437116e-06,
    1.3839713097724538e-06,
    1.4412998614011962e-06,
    1.5486284130299385e-06,
    1.665956964658681e-06,
    1.7133285516287423e-06
    ]

y11=[]
y0=[6.966427581437116e-07, 8.039713097724538e-07, 8.552998614011961e-07, 9.786284130299385e-07, 1.095956964658681e-06, 1.1433285516287422e-06]
for yy in y1:
    y11.append(yy-0.6e-6)
    # y0.append(yy-0.57e-6)
# print(y0)
y1=y11
print(y1)
y2 = [3.895e-07, 4.5255e-07, 5.013282267521897e-07, 5.99124773089139e-07, 6.569332470223632e-07, 6.7075037296058803e-07]

y3 = [2.7335e-07, 3.32218085e-07, 3.75668121e-07, 4.113561e-07, 4.7809232e-07, 5.65574968e-07]

# 绘制折线图
plt.plot(x, y0, label='ideal', color='lightpink',marker='o')

plt.plot(x, y1, label='irs with opt', color='blue',marker='+')
plt.plot(x, y2, label='irs without opt', color='red',marker='v')
plt.plot(x, y3, label='without irs', color='green',marker='^')

# 添加图例
plt.legend(loc='lower right')

# 添加标题和坐标轴标签
# plt.title('User Rewards')
plt.xlabel('User Count')
plt.ylabel('P / dbm')
plt.grid(ls=':',c='blue')
plt.savefig('figs/picture.png',dpi=1000)
# 显示图形

plt.show()
# Out:
# [6.866427581437116e-07, 7.839713097724538e-07, 8.412998614011962e-07, 9.486284130299385e-07, 1.065956964658681e-06, 1.1133285516287423e-06]

# %%
print (2.273285516287423e-07*5)
print (2.273285516287423e-07*6)
print (2.273285516287423e-07*7)
print (2.273285516287423e-07*8)
print (2.273285516287423e-07*9)
print (2.273285516287423e-07*10)
# Out:
# 1.1366427581437116e-06
# 1.3639713097724538e-06
# 1.5912998614011962e-06
# 1.8186284130299385e-06
# 2.045956964658681e-06
# 2.273285516287423e-06

# %%
import matplotlib.pyplot as plt

# 横坐标：用户数从5到10
x = [5, 6, 7, 8, 9, 10]

# 纵坐标：用户处奖励（假设有三条折线）
# y1 = [10, 15, 12, 8, 13, 9]
# y2 = [4.895e-07, 5.5255e-07, 6.023282267521897e-07, 6.409124773089139e-07, 7.169332470223632e-07, 8.075037296058803e-07]
# y1 = [0.00022173017673947327,0.0002660762120873679,0.0003104222474352626]
y1=[
    1880.756,
    1799.385,
    1821.979,
    2034.888,
    1985.777,
    2000.123,
    ]

y11=[]
y0=[6.966427581437116e-07, 8.039713097724538e-07, 8.552998614011961e-07, 9.786284130299385e-07, 1.095956964658681e-06, 1.1433285516287422e-06]
for yy in y1:
    y11.append(yy-0.6e-6)
    # y0.append(yy-0.57e-6)
# print(y0)
y1=y11
print(y1)
y2 = [3.895e-07, 4.5255e-07, 5.013282267521897e-07, 5.99124773089139e-07, 6.569332470223632e-07, 6.7075037296058803e-07]
y2=[
    1880.756,
    1799.385,
    1821.979,
    2078.888,
    1985.777,
    2000.123,
    ]
y2 = [
    3070,
    3200,
    3339,
    3485,
    3556,
    3689]

# 绘制折线图
# plt.plot(x, y0, label='ideal', color='lightpink',marker='o')
plt.plot(x, y1, label='ppo', color='blue',marker='^')
plt.plot(x, y2, label='math method', color='red',marker='o')
# plt.plot(x, y3, label='without irs', color='green',marker='^')

# 添加图例
# plt.legend(loc='lower right')
plt.legend()
# 添加标题和坐标轴标签
# plt.title('User Rewards')
plt.xlabel('User Count')
plt.ylabel('time / s')
plt.grid(ls=':',c='blue')
plt.savefig('figs/xiaolv.png',dpi=1000)
# 显示图形

plt.show()
# Out:
# [1880.7559994, 1799.3849994, 1821.9789994, 2034.8879994, 1985.7769994, 2000.1229994]

# %%
# -*- coding: gbk32 -*-
import matplotlib.pyplot as plt

# 横坐标：用户数从5到10
x = [5, 6, 7, 8, 9, 10]

# 纵坐标：用户处奖励（假设有三条折线）
# y1 = [10, 15, 12, 8, 13, 9]
# y2 = [4.895e-07, 5.5255e-07, 6.023282267521897e-07, 6.409124773089139e-07, 7.169332470223632e-07, 8.075037296058803e-07]
# y1 = [0.00022173017673947327,0.0002660762120873679,0.0003104222474352626]
y1=[
    1880.756,
    1799.385,
    1821.979,
    2034.888,
    1985.777,
    2000.123,
    ]

y11=[]
y0=[6.966427581437116e-07, 8.039713097724538e-07, 8.552998614011961e-07, 9.786284130299385e-07, 1.095956964658681e-06, 1.1433285516287422e-06]
for yy in y1:
    y11.append(yy-0.6e-6)
    # y0.append(yy-0.57e-6)
# print(y0)
y1=y11
# print(y1)
y2 = [3.895e-07, 4.5255e-07, 5.013282267521897e-07, 5.99124773089139e-07, 6.569332470223632e-07, 6.7075037296058803e-07]
y2=[
    1880.756,
    1799.385,
    1821.979,
    2078.888,
    1985.777,
    2000.123,
    ]
y2 = [
    3070,
    3200,
    3339,
    3485,
    3556,
    3689]

# 绘制折线图
# plt.plot(x, y0, label='ideal', color='lightpink',marker='o')
plt.plot(x, y1, color='blue',marker='^')
# plt.plot(x, y2, label='math method', color='orange',marker='o')
# plt.plot(x, y3, label='without irs', color='green',marker='^')

# 添加图例
# plt.legend(loc='lower right')
plt.legend()
# 添加标题和坐标轴标签
# plt.title('User Rewards')
plt.xlabel('AP处 / dBm')
plt.ylabel('P / dBm')
# plt.grid(ls=':',c='blue')
plt.savefig('figs/xiaolv222.png',dpi=1000)
# 显示图形

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /var/folders/_8/c8db2d9n42gdh_rz1kttpsbh0000gn/T/ipykernel_30776/4011782273.py:59: UserWarning: Glyph 22788 (\N{CJK UNIFIED IDEOGRAPH-5904}) missing from current font.
#   plt.savefig('figs/xiaolv222.png',dpi=1000)
# /Users/lhd/Library/Python/3.9/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 22788 (\N{CJK UNIFIED IDEOGRAPH-5904}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# from sklearn.cluster import KMeans
from sklearn.cluster import KMeans


def group_points(coordinates, M):
        # 创建K-means模型
        kmeans = KMeans(n_clusters=M)

        # 拟合模型
        kmeans.fit(coordinates)

        # 获取每个点的标签
        labels = kmeans.labels_

        # 根据标签分组
        groups = [[] for _ in range(M)]
        for i, label in enumerate(labels):
            groups[label].append(coordinates[i])

        return groups
users=[(40,3),(44,0),(42,1),(50,5)]
groups =group_points(users, 3)
    
print(groups)
# Out:
# [[(40, 3)], [(50, 5)], [(44, 0), (42, 1)]]
# /usr/local/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
a=[]
a.append(1)
a
# Out:
# [1]

# %%
r=[1,2,3]
r.sum
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 2
#       1 r=[1,2,3]
# ----> 2 r.sum
#
# AttributeError: 'list' object has no attribute 'sum'
